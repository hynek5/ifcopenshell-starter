# %% [markdown]
# <a href="https://colab.research.google.com/github/hynek5/ifcopenshell-starter/blob/dev_Nazli/google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # IfcOpenShell Starter — Colab
#
# This notebook builds an IFC model from the repo's CSV files (`layout.csv`, `connections.csv`, `uhc_library.csv`), then runs the flow calculation report.
#
# **Run all cells** (Runtime → Run all). You can then download `output.ifc` from the file browser or use the download cell at the end.

# %%
# Install ifcopenshell (required for IFC read/write)
# !pip install -q ifcopenshell

# %%
# Clone repo so we have layout.csv, connections.csv, uhc_library.csv, main.py, calc_flow.py
import os
REPO = "https://github.com/hynek5/ifcopenshell-starter.git"
BRANCH = "dev_Nazli"  # or "main"

if not os.path.isdir("ifcopenshell-starter"):
    # !git clone -b {BRANCH} --single-branch {REPO}
os.chdir("ifcopenshell-starter")
print("Working in:", os.getcwd())

# %%
# Build IFC from layout.csv, connections.csv, uhc_library.csv
# !python main.py

# %%
# Run flow calculation (Stack Pipe, UHC sum, diameter)
# !python calc_flow.py

# %% [markdown]
# ## Download output.ifc
#
# Use the **Files** panel on the left to download `output.ifc`, or run the cell below to get a direct download link.

# %%
from google.colab import files
import os
ifc_path = "output.ifc"
if os.path.isfile(ifc_path):
    files.download(ifc_path)
else:
    print("Run main.py first (previous cells).")
